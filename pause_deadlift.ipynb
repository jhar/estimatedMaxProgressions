# %%
# %run ./shared_functions.ipynb

pauseDeadliftLog = [
    ("6/25/2023", 394.56),
    ("7/1/2023", 362.56),
    ("7/7/2023", 352.68),
    ("7/13/2023", 365.37),
    ("7/19/2023", 376.61),
    ("7/25/2023", 357.99),
    ("7/31/2023", 360.64),
    ("8/6/2023", 363.29),
    ("8/12/2023", 365.94),
    ("8/18/2023", 368.59),
    ("8/24/2023", 379.52),
]

plotWithRegression(pauseDeadliftLog, "Pause Deadlift")
